# %%
from jaqs_fxdayu.data import RemoteDataService  # 远程数据服务类

# step 1 其中，username password分别对应官网注册的账号和序列号
data_config = {
    "remote.data.address": "tcp://192.168.0.101:23000",  # 数据服务tcp地址
    "remote.data.username": "18566262672",  # 账号
    "remote.data.password": "eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTI3MDI3NTAyMTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTg1NjYyNjI2NzIifQ.O_-yR0zYagrLRvPbggnru1Rapk4kiyAzcwYt2a3vlpM",
    "timeout": 180  # 超时设置(秒),请求超时会报错
}

# step 2
ds = RemoteDataService()
ds.init_from_config(data_config)
# Out:
# Begin: DataApi login 18566262672@tcp://192.168.0.101:23000
#     login success
# '0,'

# %%
members = ds.query_index_member_daily("000906.SH", 20171101, 20180201)

# %%
members.drop_duplicates()
# Out:
#             000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# trade_date
# 20171101            1          1          1          1          1          1
# 20171208            1          1          1          1          1          1
# 20171212            1          1          1          1          1          1
#
#             000021.SZ  000025.SZ  000027.SZ  000028.SZ    ...      603806.SH  \
# trade_date                                                ...
# 20171101            1          1          1          1    ...              1
# 20171208            1          1          1          1    ...              1
# 20171212            1          1          1          1    ...              1
#
#             603816.SH  603833.SH  603858.SH  603866.SH  603868.SH  603877.SH  \
# trade_date
# 20171101            1          0          1          1          1          1
# 20171208            1          0          1          0          1          1
# ...

# %%
from jaqs_fxdayu.data import DataView
dv = DataView()

# %%
from jaqs_fxdayu.data import DataView
dv1 = DataView()
props = {'start_date': 20171101, 'end_date': 20171207,  # 'symbol': ",".join(combined),
         "universe": "000906.SH",  # "universe": "000906.SH, 000852.SH",
         # "benchmark": "000906.SH",  # "000300.SH",
         "prepare_fields": True,
         'fields': "float_mv,MA5,RSI,VOL10",
         'freq': 1}
dv1.init_from_config(props, ds)
dv1.prepare_data()
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'symbol,high,vwap_adj,low_adj,vwap,open_adj,high_adj,low,trade_status,trade_date,close,open,close_adj'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'high,vwap,low,close,open,symbol,trade_date'}
# 当前请求query_lb_dailyindicator...
# {'fields': 'float_mv,trade_date,symbol'}
# WARNING: some data is unavailable:
#     At fields
# Query data - daily fields prepared.
# Query instrument info...
# Query adj_factor...
# Query benchmark...
# Query benchmar member info...
# Data has been successfully prepared.

# %%
from jaqs_fxdayu.data import DataView
dv2 = DataView()
props = {'start_date': 20171208, 'end_date': 20180115,  # 'symbol': ",".join(combined),
         "universe": "000906.SH",  # "universe": "000906.SH, 000852.SH",
         # "benchmark": "000906.SH",  # "000300.SH",
         "prepare_fields": True,
         'fields': "float_mv,MA5,RSI,VOL10",
         'freq': 1}
dv2.init_from_config(props, ds)
dv2.prepare_data()
# Out:
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'symbol,high,vwap_adj,low_adj,vwap,open_adj,high_adj,low,trade_status,trade_date,close,open,close_adj'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'high,vwap,low,close,open,symbol,trade_date'}
# 当前请求query_lb_dailyindicator...
# {'fields': 'float_mv,trade_date,symbol'}
# WARNING: some data is unavailable:
#     At fields
# Query data - daily fields prepared.
# Query instrument info...
# Query adj_factor...
# Query benchmark...
# Query benchmar member info...
# Data has been successfully prepared.

# %%
new_symbols = set(dv2.symbol)-set(dv1.symbol)
old_symbols = set(dv1.symbol)-set(dv2.symbol)
print(new_symbols)
print(old_symbols)
# Out:
# {'300197.SZ', '603833.SH', '600908.SH', '600939.SH', '000990.SZ', '000898.SZ', '000987.SZ', '600875.SH', '600155.SH', '601991.SH', '601898.SH', '600346.SH', '002745.SZ', '600004.SH', '300015.SZ', '601212.SH', '000723.SZ', '000807.SZ', '601969.SH', '002608.SZ', '601228.SH', '600598.SH', '002280.SZ', '600390.SH', '002032.SZ', '600011.SH', '600885.SH', '601878.SH', '600578.SH', '600438.SH', '300182.SZ', '600823.SH', '002434.SZ', '002624.SZ', '601128.SH', '601200.SH', '002506.SZ', '600575.SH', '603225.SH', '002294.SZ', '000981.SZ', '600393.SH', '600317.SH', '600179.SH', '300003.SZ', '002359.SZ', '600623.SH', '000887.SZ'}
# set()

# %%
dv1.dates
# Out:
# array([20170906, 20170907, 20170908, 20170911, 20170912, 20170913,
#        20170914, 20170915, 20170918, 20170919, 20170920, 20170921,
#        20170922, 20170925, 20170926, 20170927, 20170928, 20170929,
#        20171009, 20171010, 20171011, 20171012, 20171013, 20171016,
#        20171017, 20171018, 20171019, 20171020, 20171023, 20171024,
#        20171025, 20171026, 20171027, 20171030, 20171031, 20171101,
#        20171102, 20171103, 20171106, 20171107, 20171108, 20171109,
#        20171110, 20171113, 20171114, 20171115, 20171116, 20171117,
#        20171120, 20171121, 20171122, 20171123, 20171124, 20171127,
#        20171128, 20171129, 20171130, 20171201, 20171204, 20171205,
#        20171206, 20171207], dtype=int64)

# %%
dv2.dates
# Out:
# array([20171013, 20171016, 20171017, 20171018, 20171019, 20171020,
#        20171023, 20171024, 20171025, 20171026, 20171027, 20171030,
#        20171031, 20171101, 20171102, 20171103, 20171106, 20171107,
#        20171108, 20171109, 20171110, 20171113, 20171114, 20171115,
#        20171116, 20171117, 20171120, 20171121, 20171122, 20171123,
#        20171124, 20171127, 20171128, 20171129, 20171130, 20171201,
#        20171204, 20171205, 20171206, 20171207, 20171208, 20171211,
#        20171212, 20171213, 20171214, 20171215, 20171218, 20171219,
#        20171220, 20171221, 20171222, 20171225, 20171226, 20171227,
#        20171228, 20171229, 20180102, 20180103, 20180104, 20180105,
#        20180108, 20180109, 20180110, 20180111, 20180112, 20180115],
#       dtype=int64)

# %%
dv1.refresh_data(20180115)
# Out:
# Field name [{'adjust_factor'}] not valid, ignore.
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'index_weight,symbol,high,vwap_adj,low_adj,vwap,open_adj,high_adj,low,index_member,trade_status,trade_date,close,open,close_adj'}
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'high,vwap,low,close,open,symbol,trade_date'}
# 当前请求query_lb_dailyindicator...
# {'fields': 'float_mv,trade_date,symbol'}
# WARNING: some data is unavailable:
#     At fields
# Query data - daily fields prepared.
# Query instrument info...
# Query adj_factor...
# Query benchmark...
# Query benchmar member info...
# Field [index_member] is overwritten.
# Field [index_weight] is overwritten.
# Data has been successfully prepared.
# Field name [{'adjust_factor'}] not valid, ignore.
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# ...

# %%
dv1.data_d.loc[:,list(new_symbols)]
# Out:
# symbol     000723.SZ                                                  \
# field            MA5      RSI   VOL10 adjust_factor close  close_adj
# trade_date
# 20170906       9.226  71.6049  0.0552      6.356799  9.19  58.418983
# 20170907       9.200  72.8033  0.0562      6.356799  9.02  57.338327
# 20170908       9.150  75.7812  0.0539      6.356799  9.22  58.609687
# 20170911       9.180  75.8755  0.0547      6.356799  9.30  59.118231
# 20170912       9.184  65.7277  0.0576      6.356799  9.19  58.418983
# 20170913       9.146  60.0000  0.0562      6.356799  9.00  57.211191
# 20170914       9.120  60.5263  0.0499      6.356799  8.89  56.511943
# 20170915       9.050  55.7692  0.0422      6.356799  8.87  56.384807
# 20170918       8.956  40.0000  0.0359      6.356799  8.83  56.130535
# 20170919       8.860  22.8571  0.0330      6.356799  8.71  55.367719
# 20170920       8.754  24.2424  0.0312      6.356799  8.47  53.842088
# ...

# %%
dv1.data_d.loc[:,"603866.SH"]
# Out:
# field          MA5      RSI   VOL10  adjust_factor  close  close_adj  \
# trade_date
# 20170906    36.394  83.9779  0.0098       1.022546  36.79  37.619467
# 20170907    36.628  80.4714  0.0099       1.022546  37.04  37.875104
# 20170908    36.958  90.0990  0.0098       1.022546  37.38  38.222769
# 20170911    37.274  92.1260  0.0097       1.022546  38.21  39.071483
# 20170912    37.576  91.7808  0.0102       1.022546  38.46  39.327119
# 20170913    37.814  80.0000  0.0102       1.022546  37.98  38.836297
# 20170914    37.944  74.0291  0.0100       1.022546  37.69  38.539759
# 20170915    38.006  73.9024  0.0097       1.022546  37.69  38.539759
# 20170918    37.798  64.5089  0.0092       1.022546  37.17  38.008035
# 20170919    37.542  66.6667  0.0087       1.022546  37.18  38.018260
# 20170920    37.438  61.1260  0.0079       1.022546  37.46  38.304573
# 20170921    37.364  55.2113  0.0070       1.022546  37.32  38.161417
# ...
